# %%
import xml.etree.cElementTree as et
import re
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
# OSM-specific constants
HONGKONG_OSM = "hong-kong_china.osm"
KEY_ELEMENTS = ["bounds"]
CORE_ELEMENTS = ["node", "way", "relation"]
# regular expressions
REGX_LOWER = re.compile(r'^([a-z]|_)*$')
REGX_LOWER_COLON = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
REGX_LOWER_PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
def key_check(key, checks):
    lower_results = REGX_LOWER.search(key)
    lower_colon_results = REGX_LOWER_COLON.search(key)
    problemchars_results = REGX_LOWER_PROBLEMCHARS.search(key)

    if lower_results:
        checks["lower"] += 1
    elif lower_colon_results:
        checks["lower_colon"] += 1
    elif problemchars_results:
        checks["problemchars"] += 1
    else:
        checks["other"] += 1
        
    return checks

# %%
def get_elements(source):
    # get an iterator
    context = et.iterparse(source, events=("start",))
    # get the root element
    event, root = context.next()
    
    elements = {}
    checks = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    
    for event, elem in context:
        if event == "start":
            tag = elem.tag
            if tag not in elements:
                elements[tag] = {"count": 0, "attributes": []}
            elements[tag]["count"] += 1
            
            other_attrs = [x for x in elem.keys() if x not in elements[tag]["attributes"]]
            if other_attrs: # not empty
                if elements[tag]["attributes"]: # not empty
                    elements[tag]["attributes"].extend(other_attrs)
                else:
                    elements[tag]["attributes"] = other_attrs
            
            if tag in CORE_ELEMENTS:
                if "features" not in elements[tag]:
                    elements[tag]["features"] = {}
                for sub in elem.iter("tag"):
                    feature = sub.get("k")
                    key_check(feature, checks)
                    if feature not in elements[tag]["features"]:
                        elements[tag]["features"][feature] = 0
                    elements[tag]["features"][feature] += 1
                    
        # reset and clear the elements from memory
        root.clear()

    return elements, checks

# %%
elements, checks = get_elements(HONGKONG_OSM)
pp.pprint(checks)
pp.pprint(elements)
# Out:
# {   'lower': 518860, 'lower_colon': 129901, 'other': 7518, 'problemchars': 1}
# {   'bounds': {   'attributes': [   'origin',
#                                     'minlat',
#                                     'maxlon',
#                                     'minlon',
#                                     'maxlat'],
#                   'count': 1},
#     'member': {   'attributes': ['ref', 'role', 'type'], 'count': 60676},
#     'nd': {   'attributes': ['ref'], 'count': 2328525},
#     'node': {   'attributes': [   'changeset',
#                                   'uid',
#                                   'timestamp',
#                                   'lon',
#                                   'version',
#                                   'user',
#                                   'lat',
#                                   'id'],
#                 'count': 2030982,
#                 'features': {   'Business': 1,
#                                 'Color': 122,
#                                 'Company': 1,
#                                 'FIXME': 2,
#                                 'Region': 1,
#                                 'S57Node': 158,
#                                 'Shape': 105,
#                                 'access': 105,
#                                 'addr:building': 2,
#                                 'addr:city': 191,
#                                 'addr:country': 13,
#                                 'addr:district': 1,
#                                 'addr:door': 179,
#                                 'addr:flats': 1,
#                                 'addr:floor': 202,
#                                 'addr:full': 4,
#                                 'addr:housename': 49,
#                                 'addr:housenumber': 682,
#                                 'addr:place': 3,
#                                 'addr:postcode': 40,
#                                 'addr:state': 1,
#                                 'addr:street': 869,
#                                 'addr:streetnumber': 1,
#                                 'addr:suburb': 3,
#                                 'addr:unit': 32,
#                                 'aerialway': 10,
#                                 'aeroway': 234,
#                                 'alt_name': 71,
#                                 'alt_name:en': 42,
#                                 'alt_name:fr': 1,
#                                 'alt_name:vi': 29,
#                                 'alt_name:zh': 26,
#                                 'alt_name:zh_pinyin': 1,
#                                 'amenity': 5890,
#                                 'area': 1123,
#                                 'artist_name': 2,
#                                 'artwork_type': 15,
#                                 'asset_ref': 431,
#                                 'atm': 200,
#                                 'attraction': 1,
#                                 'backrest': 11,
#                                 'barbecue_grill': 1,
#                                 'barrier': 2576,
#                                 'bbq': 7,
#                                 'bench': 19,
#                                 'bic': 3,
#                                 'bicycle': 307,
#                                 'bitcoin:atm': 1,
#                                 'board_type': 1,
#                                 'bollard': 2,
#                                 'bottle': 1,
#                                 'boundary': 1,
#                                 'branch': 5,
#                                 'brand': 94,
#                                 'bridge': 2,
#                                 'building': 198,
#                                 'building:levels': 3,
#                                 'bus': 35,
#                                 'button_operated': 2,
#                                 'camera:type': 5,
#                                 'capacity': 34,
#                                 'capacity:parent': 1,
#                                 'capacity:women': 1,
#                                 'car': 1,
#                                 'cargo': 2,
#                                 'china_class': 70,
#                                 'city_served': 3,
#                                 'cityname': 129,
#                                 'closest_town': 1,
#                                 'collection_times': 51,
#                                 'color': 3,
#                                 'colour': 11,
#                                 'comment': 3,
#                                 'construction': 23,
#                                 'contact:email': 1,
#                                 'contact:phone': 2,
#                                 'contact:website': 1,
#                                 'cooled': 1,
#                                 'country': 11,
#                                 'countryname': 128,
#                                 'covered': 20,
#                                 'craft': 2,
#                                 'crane:note': 30,
#                                 'crane:type': 30,
#                                 'created_by': 812,
#                                 'crossing': 4429,
#                                 'crossing_ref': 1023,
#                                 'cuisine': 406,
#                                 'datalevel': 2,
#                                 'denomination': 27,
#                                 'description': 8,
#                                 'designation': 26,
#                                 'destination': 86,
#                                 'destination:en': 86,
#                                 'destination:zh': 86,
#                                 'destination:zh-yue': 86,
#                                 'diet:vegan': 10,
#                                 'diet:vegetarian': 10,
#                                 'direction': 73,
#                                 'dispensing': 2,
#                                 'display': 2,
#                                 'distance': 2,
#                                 'disused': 2,
#                                 'drinking_water': 3,
#                                 'drinking_water:bottle': 1,
#                                 'drive_through': 1,
#                                 'ele': 426,
#                                 'elevation': 1,
#                                 'email': 24,
#                                 'emergency': 78,
#                                 'end_date': 1,
#                                 'enterance': 1,
#                                 'entrance': 480,
#                                 'exit_to': 2,
#                                 'fax': 36,
#                                 'fee': 98,
#                                 'female': 1,
#                                 'ferry': 3,
#                                 'fire_hydrant:type': 28,
#                                 'fire_hydrant:water_source': 1,
#                                 'fireplace': 2,
#                                 'fixme': 11,
#                                 'flag:type': 1,
#                                 'floating': 1,
#                                 'floor': 8,
#                                 'food': 2,
#                                 'foot': 590,
#                                 'forest': 1,
#                                 'fty': 4,
#                                 'fuel:diesel': 2,
#                                 'fuel:e85': 1,
#                                 'fuel:lpg': 2,
#                                 'garmin_type': 213,
#                                 'generator:method': 8,
#                                 'generator:output:electricity': 6,
#                                 'generator:source': 67,
#                                 'generator:type': 8,
#                                 'genus': 18,
#                                 'gns:ADM1': 36,
#                                 'gns:DSG': 37,
#                                 'gns:UFI': 37,
#                                 'gns:UNI': 37,
#                                 'height': 4,
#                                 'highway': 14705,
#                                 'highwayidx': 1,
#                                 'hiking': 5,
#                                 'historic': 110,
#                                 'history': 1,
#                                 'home': 1,
#                                 'horse': 13,
#                                 'iata': 5,
#                                 'icao': 6,
#                                 'indoor': 3,
#                                 'information': 1221,
#                                 'int_name': 65,
#                                 'internet_access': 28,
#                                 'internet_access:fee': 12,
#                                 'is_in': 38,
#                                 'is_in:continent': 51,
#                                 'is_in:country': 7,
#                                 'is_in:country_code': 6,
#                                 'is_in:theme_park': 13,
#                                 'junction': 6,
#                                 'key': 2,
#                                 'kml_folder': 11,
#                                 'ladder': 1,
#                                 'landmark': 2,
#                                 'landuse': 26,
#                                 'layer': 48,
#                                 'leisure': 227,
#                                 'level': 209,
#                                 'light_rail': 198,
#                                 'lit': 2,
#                                 'lobby_floor': 1,
#                                 'loc_name': 21,
#                                 'loc_ref': 26,
#                                 'local_ref': 4,
#                                 'location': 64,
#                                 'location_id': 19,
#                                 'location_id:': 1,
#                                 'locked': 1,
#                                 'male': 1,
#                                 'man_made': 200,
#                                 'man_made_wrong': 1,
#                                 'map_size': 5,
#                                 'map_type': 5,
#                                 'marine': 136,
#                                 'material': 10,
#                                 'maxheight': 9,
#                                 'maxspeed': 11,
#                                 'maxtents': 1,
#                                 'memorial': 2,
#                                 'metcouncil:route_4': 1,
#                                 'metcouncil:routea_2': 1,
#                                 'metcouncil:routes_1': 2,
#                                 'metcouncil:routes_2': 1,
#                                 'metcouncil:routes_3': 2,
#                                 'microbrewery': 3,
#                                 'military': 2,
#                                 'mineral': 14,
#                                 'monument': 1,
#                                 'motor_vehicle': 10,
#                                 'motorcar': 36,
#                                 'motorcycle': 33,
#                                 'mountain_pass': 6,
#                                 'mp_type': 135,
#                                 'name': 20523,
#                                 'name:': 9,
#                                 'name:English Code': 1,
#                                 'name:bn': 1,
#                                 'name:botanical': 1,
#                                 'name:ca': 1,
#                                 'name:da': 2,
#                                 'name:de': 17,
#                                 'name:en': 8702,
#                                 'name:es': 6,
#                                 'name:fr': 59,
#                                 'name:he': 1,
#                                 'name:hi': 3,
#                                 'name:hr': 1,
#                                 'name:int_name': 1,
#                                 'name:international': 1,
#                                 'name:ja': 3,
#                                 'name:ka': 1,
#                                 'name:kn': 4,
#                                 'name:ko': 1,
#                                 'name:ku': 3,
#                                 'name:latin': 1,
#                                 'name:lt': 2,
#                                 'name:nl': 2,
#                                 'name:pinyin': 1,
#                                 'name:pl': 1,
#                                 'name:pt': 536,
#                                 'name:ru': 11,
#                                 'name:short': 1,
#                                 'name:simple': 2,
#                                 'name:sn': 3,
#                                 'name:sr': 5,
#                                 'name:ta': 2,
#                                 'name:tt': 1,
#                                 'name:uk': 4,
#                                 'name:vi': 196,
#                                 'name:yue': 7,
#                                 'name:zh': 8614,
#                                 'name:zh-hant': 26,
#                                 'name:zh-yue': 335,
#                                 'name:zh_pinyin': 175,
#                                 'name:zh_py': 6,
#                                 'name:zh_pyt': 1,
#                                 u'name:\u6208\u65e5': 1,
#                                 'name_3': 1,
#                                 'name_4': 1,
#                                 'name_5': 1,
#                                 'naptan:Bearing': 40,
#                                 'naptan:Street': 2,
#                                 'natural': 1713,
#                                 'network': 58,
#                                 'noexit': 16,
#                                 'note': 465,
#                                 'notes': 3,
#                                 'occupied_floors': 1,
#                                 'office': 54,
#                                 'official_name': 29,
#                                 'official_name:en': 15,
#                                 'official_name:es': 1,
#                                 'official_name:fr': 1,
#                                 'official_name:pt': 11,
#                                 'official_name:ru': 1,
#                                 'official_name:vi': 1,
#                                 'official_name:zh': 24,
#                                 'old_name': 21,
#                                 'old_name:en': 6,
#                                 'old_name:nl': 1,
#                                 'old_name:pt': 13,
#                                 'old_name:ru': 1,
#                                 'old_name:vi': 2,
#                                 'old_name:zh': 18,
#                                 'old_name:zh-yue': 3,
#                                 'oneway': 2,
#                                 'opening_hours': 191,
#                                 'operator': 1189,
#                                 'operator:en': 2,
#                                 'operator:wikidata': 196,
#                                 'operator:zh': 2,
#                                 'organic': 1,
#                                 'outdoor_seating': 1,
#                                 'overnightparking': 1,
#                                 'owner': 1,
#                                 'park_ride': 1,
#                                 'parking': 273,
#                                 'payment': 1,
#                                 'payment:bitcoin': 26,
#                                 'payment:coins': 17,
#                                 'payment:electronic_purses': 5,
#                                 'payment:litecoin': 1,
#                                 'payment:notes': 1,
#                                 'phone': 221,
#                                 'place': 5414,
#                                 'platform': 1,
#                                 'platforms': 178,
#                                 'population': 11,
#                                 'power': 11037,
#                                 'power_source': 26,
#                                 'public_transport': 681,
#                                 'railway': 2226,
#                                 'rank': 1,
#                                 'recycling:cans': 26,
#                                 'recycling:glass': 2,
#                                 'recycling:paper': 26,
#                                 'recycling:plastic': 1,
#                                 'recycling:scrap_metal': 23,
#                                 'recycling_type': 5,
#                                 'ref': 1662,
#                                 'ref:CBNW': 11,
#                                 'ref:cbnw': 26,
#                                 'ref:ctb': 1108,
#                                 'ref:en': 4,
#                                 'ref:hkbus': 3441,
#                                 'ref:kmb': 2005,
#                                 'ref:nwfb': 12,
#                                 'ref:nwstbus': 2,
#                                 'ref:vi': 4,
#                                 'refrigerated': 1,
#                                 'refugee': 1,
#                                 'reg_name': 1,
#                                 'region': 61,
#                                 'regionname': 128,
#                                 'religion': 112,
#                                 'route_ref': 483,
#                                 'route_ref_1': 1,
#                                 'royal_cypher': 6,
#                                 'ruins': 1,
#                                 'school': 1,
#                                 'seamark:beacon_cardinal:category': 3,
#                                 'seamark:beacon_cardinal:colour': 3,
#                                 'seamark:beacon_cardinal:colour_pattern': 3,
#                                 'seamark:beacon_isolated_danger:colour': 5,
#                                 'seamark:beacon_isolated_danger:colour_pattern': 4,
#                                 'seamark:beacon_lateral:category': 9,
#                                 'seamark:beacon_lateral:colour': 9,
#                                 'seamark:beacon_lateral:system': 9,
#                                 'seamark:beacon_special_purpose:colour': 2,
#                                 'seamark:bridge:category': 10,
#                                 'seamark:bridge:clearance_height': 10,
#                                 'seamark:buoy_cardinal:category': 13,
#                                 'seamark:buoy_cardinal:colour': 14,
#                                 'seamark:buoy_cardinal:colour_pattern': 13,
#                                 'seamark:buoy_cardinal:shape': 13,
#                                 'seamark:buoy_isolated_danger:colour': 3,
#                                 'seamark:buoy_isolated_danger:colour_pattern': 3,
#                                 'seamark:buoy_isolated_danger:shape': 2,
#                                 'seamark:buoy_lateral:category': 55,
#                                 'seamark:buoy_lateral:colour': 62,
#                                 'seamark:buoy_lateral:shape': 62,
#                                 'seamark:buoy_lateral:system': 55,
#                                 'seamark:buoy_safe_water:colour': 17,
#                                 'seamark:buoy_safe_water:colour_pattern': 17,
#                                 'seamark:buoy_safe_water:shape': 17,
#                                 'seamark:buoy_special_purpose:colour': 33,
#                                 'seamark:buoy_special_purpose:shape': 33,
#                                 'seamark:cable_overhead:vertical_clearance_safe': 1,
#                                 'seamark:fixme': 1,
#                                 'seamark:fog_signal:category': 5,
#                                 'seamark:fog_signal:group': 1,
#                                 'seamark:fog_signal:period': 2,
#                                 'seamark:harbour:category': 4,
#                                 'seamark:information': 54,
#                                 'seamark:landmark:category': 12,
#                                 'seamark:light:1:category': 2,
#                                 'seamark:light:1:character': 20,
#                                 'seamark:light:1:colour': 21,
#                                 'seamark:light:1:group': 8,
#                                 'seamark:light:1:height': 21,
#                                 'seamark:light:1:multiple': 2,
#                                 'seamark:light:1:period': 20,
#                                 'seamark:light:1:range': 20,
#                                 'seamark:light:1:sector_end': 20,
#                                 'seamark:light:1:sector_start': 20,
#                                 'seamark:light:1:sequence': 11,
#                                 'seamark:light:2:character': 8,
#                                 'seamark:light:2:colour': 8,
#                                 'seamark:light:2:group': 3,
#                                 'seamark:light:2:height': 8,
#                                 'seamark:light:2:period': 8,
#                                 'seamark:light:2:range': 8,
#                                 'seamark:light:2:sector_end': 6,
#                                 'seamark:light:2:sector_start': 6,
#                                 'seamark:light:2:sequence': 6,
#                                 'seamark:light:3:character': 2,
#                                 'seamark:light:3:colour': 2,
#                                 'seamark:light:3:height': 2,
#                                 'seamark:light:3:period': 2,
#                                 'seamark:light:3:range': 2,
#                                 'seamark:light:3:sector_end': 2,
#                                 'seamark:light:3:sector_start': 2,
#                                 'seamark:light:3:sequence': 2,
#                                 'seamark:light:4:character': 1,
#                                 'seamark:light:4:colour': 1,
#                                 'seamark:light:4:height': 1,
#                                 'seamark:light:4:period': 1,
#                                 'seamark:light:4:range': 1,
#                                 'seamark:light:4:sector_end': 1,
#                                 'seamark:light:4:sector_start': 1,
#                                 'seamark:light:4:sequence': 1,
#                                 'seamark:light:5:character': 1,
#                                 'seamark:light:5:colour': 1,
#                                 'seamark:light:5:height': 1,
#                                 'seamark:light:5:period': 1,
#                                 'seamark:light:5:range': 1,
#                                 'seamark:light:5:sector_end': 1,
#                                 'seamark:light:5:sector_start': 1,
#                                 'seamark:light:5:sequence': 1,
#                                 'seamark:light:category': 6,
#                                 'seamark:light:character': 343,
#                                 'seamark:light:colour': 347,
#                                 'seamark:light:group': 108,
#                                 'seamark:light:height': 192,
#                                 'seamark:light:information': 3,
#                                 'seamark:light:locref': 4,
#                                 'seamark:light:period': 277,
#                                 'seamark:light:range': 182,
#                                 'seamark:light:reference': 168,
#                                 'seamark:light:sequence': 15,
#                                 'seamark:light_major:height': 10,
#                                 'seamark:light_minor:height': 39,
#                                 'seamark:mooring': 9,
#                                 'seamark:mooring:category': 94,
#                                 'seamark:mooring:colour': 3,
#                                 'seamark:name': 255,
#                                 'seamark:name:en': 84,
#                                 'seamark:name:zh': 84,
#                                 'seamark:radar_reflector': 12,
#                                 'seamark:radar_transponder:category': 7,
#                                 'seamark:radar_transponder:group': 7,
#                                 'seamark:topmark': 3,
#                                 'seamark:topmark:colour': 54,
#                                 'seamark:topmark:shape': 55,
#                                 'seamark:type': 511,
#                                 'seamark:wreck:category': 2,
#                                 'seats': 11,
#                                 'service': 33,
#                                 'service:bicycle:rental': 4,
#                                 'service:bicycle:repair': 1,
#                                 'service:bicycle:retail': 2,
#                                 'service:bicycle:second_hand': 1,
#                                 'shelter': 1518,
#                                 'shelter_type': 16,
#                                 'shop': 984,
#                                 'short_name': 27,
#                                 'smoking': 14,
#                                 'social_facility': 1,
#                                 'social_facility:for': 2,
#                                 'source': 1102,
#                                 'source:cuisine': 2,
#                                 'source:name': 19,
#                                 'source:opening_hours': 4,
#                                 'source:operator': 5,
#                                 'source:phone': 1,
#                                 'source:population': 1,
#                                 'species': 50,
#                                 'sport': 26,
#                                 'stars': 7,
#                                 'start_date': 210,
#                                 'station': 27,
#                                 'streetdesc': 9,
#                                 'subway': 168,
#                                 'supervised': 36,
#                                 'support': 1,
#                                 'surface': 2,
#                                 'surveillance': 8,
#                                 'surveillance:type': 1,
#                                 'surveillance:zone': 1,
#                                 'survey:date': 1,
#                                 'tactile_paving': 4,
#                                 'takeaway': 1,
#                                 'temperature': 1,
#                                 'tents': 1,
#                                 'to_add': 6,
#                                 'toilets': 1,
#                                 'toilets:disposal': 64,
#                                 'toilets:position': 1,
#                                 'tourism': 2343,
#                                 'tower:type': 8,
#                                 'traffic_calming': 61,
#                                 'traffic_signals:direction': 3,
#                                 'train': 9,
#                                 'tram': 118,
#                                 'type': 1750,
#                                 'url': 4,
#                                 'vending': 26,
#                                 'verify': 4,
#                                 'waterway': 30,
#                                 'website': 224,
#                                 'wheelchair': 373,
#                                 'width': 1,
#                                 'wifi': 7,
#                                 'wikidata': 69,
#                                 'wikipedia': 175,
#                                 'wikipedia:en': 6,
#                                 'wpt_description': 16,
#                                 'wpt_symbol': 15,
#                                 u'\u68ee\u6797': 1}},
#     'relation': {   'attributes': [   'changeset',
#                                       'uid',
#                                       'timestamp',
#                                       'version',
#                                       'user',
#                                       'id'],
#                     'count': 5620,
#                     'features': {   'FIXME': 1,
#                                     'ISO3166-1': 2,
#                                     'ISO3166-2': 3,
#                                     'Region': 1,
#                                     'addr:city': 3,
#                                     'addr:district': 1,
#                                     'addr:housenumber': 16,
#                                     'addr:postcode': 1,
#                                     'addr:province': 1,
#                                     'addr:street': 14,
#                                     'admin_level': 79,
#                                     'aerodrome': 1,
#                                     'aeroway': 1,
#                                     'alt_name': 27,
#                                     'alt_name:en': 11,
#                                     'alt_name:vi': 1,
#                                     'alt_name:zh': 1,
#                                     'alt_name:zh-yue': 1,
#                                     'amenity': 16,
#                                     'area': 7,
#                                     'boundary': 79,
#                                     'building': 150,
#                                     'building:levels': 74,
#                                     'building:min_level': 1,
#                                     'bus': 1,
#                                     'china_class': 13,
#                                     'code': 23,
#                                     'color': 4,
#                                     'colour': 40,
#                                     'comment': 1,
#                                     'date_on': 5,
#                                     'date_start': 1,
#                                     'description': 9,
#                                     'designation': 3,
#                                     'destination': 2,
#                                     'distance': 1,
#                                     'duration': 1,
#                                     'ele': 1,
#                                     'except': 28,
#                                     'fax': 38,
#                                     'fee': 9,
#                                     'fixme': 2,
#                                     'flag': 1,
#                                     'from': 11,
#                                     'from:en': 3,
#                                     'from:zh': 3,
#                                     'from:zh-yue': 3,
#                                     'golf': 1,
#                                     'highway': 10,
#                                     'hour_on': 4,
#                                     'iata': 1,
#                                     'icao': 1,
#                                     'int_name': 1,
#                                     'int_ref': 1,
#                                     'is_in': 3,
#                                     'is_in:continent': 1,
#                                     'is_in:country_code': 1,
#                                     'isced:level': 1,
#                                     'landuse': 63,
#                                     'lanes': 1,
#                                     'lanes:extra': 1,
#                                     'layer': 43,
#                                     'leisure': 64,
#                                     'length': 1,
#                                     'lengths:right': 1,
#                                     'man_made': 2,
#                                     'maxlength': 12,
#                                     'military': 2,
#                                     'name': 708,
#                                     'name:ab': 1,
#                                     'name:af': 1,
#                                     'name:am': 1,
#                                     'name:an': 1,
#                                     'name:ar': 1,
#                                     'name:ay': 1,
#                                     'name:az': 1,
#                                     'name:ba': 1
# ,
#                                     'name:be': 1,
#                                     'name:bg': 1,
#                                     'name:bh': 1,
#                                     'name:bi': 1,
#                                     'name:bm': 1,
#                                     'name:bn': 1,
#                                     'name:bo': 1,
#                                     'name:br': 1,
#                                     'name:bs': 1,
#                                     'name:ca': 1,
#                                     'name:ce': 1,
#                                     'name:cs': 1,
#                                     'name:cu': 1,
#                                     'name:cv': 1,
#                                     'name:cy': 1,
#                                     'name:da': 2,
#                                     'name:de': 6,
#                                     'name:dv': 1,
#                                     'name:ee': 1,
#                                     'name:el': 1,
#                                     'name:en': 352,
#                                     'name:eo': 1,
#                                     'name:es': 2,
#                                     'name:et': 1,
#                                     'name:eu': 1,
#                                     'name:fa': 1,
#                                     'name:fi': 1,
#                                     'name:fo': 1,
#                                     'name:fr': 4,
#                                     'name:fy': 1,
#                                     'name:ga': 1,
#                                     'name:gd': 1,
#                                     'name:gl': 1,
#                                     'name:gn': 1,
#                                     'name:gu': 1,
#                                     'name:gv': 1,
#                                     'name:ha': 1,
#                                     'name:he': 2,
#                                     'name:hi': 1,
#                                     'name:hr': 1,
#                                     'name:hu': 1,
#                                     'name:hy': 1,
#                                     'name:ia': 1,
#                                     'name:id': 1,
#                                     'name:ie': 1,
#                                     'name:io': 1,
#                                     'name:is': 1,
#                                     'name:it': 1,
#                                     'name:iu': 1,
#                                     'name:ja': 1,
#                                     'name:jv': 1,
#                                     'name:ka': 2,
#                                     'name:kg': 1,
#                                     'name:ki': 1,
#                                     'name:kk': 1,
#                                     'name:kl': 1,
#                                     'name:kn': 2,
#                                     'name:ko': 1,
#                                     'name:ks': 1,
#                                     'name:ku': 1,
#                                     'name:kv': 1,
#                                     'name:kw': 1,
#                                     'name:ky': 1,
#                                     'name:la': 1,
#                                     'name:lb': 1,
#                                     'name:li': 1,
#                                     'name:ln': 1,
#                                     'name:lo': 1,
#                                     'name:lt': 2,
#                                     'name:lv': 1,
#                                     'name:mg': 1,
#                                     'name:mi': 1,
#                                     'name:mk': 1,
#                                     'name:ml': 1,
#                                     'name:mn': 1,
#                                     'name:mr': 1,
#                                     'name:ms': 1,
#                                     'name:mt': 1,
#                                     'name:my': 1,
#                                     'name:na': 1,
#                                     'name:ne': 1,
#                                     'name:nl': 2,
#                                     'name:nn': 1,
#                                     'name:no': 1,
#                                     'name:oc': 1,
#                                     'name:or': 1,
#                                     'name:os': 1,
#                                     'name:pa': 1,
#                                     'name:pl': 5,
#                                     'name:pt': 44,
#                                     'name:ru': 10,
#                                     'name:sr': 1,
#                                     'name:tt': 1,
#                                     'name:uk': 1,
#                                     'name:vi': 6,
#                                     'name:zh': 309,
#                                     'name:zh-hant': 4,
#                                     'name:zh-py': 1,
#                                     'name:zh-yue': 50,
#                                     'name:zh_pinyin': 56,
#                                     'natural': 508,
#                                     'network': 133,
#                                     'note': 7,
#                                     'nsdi_code': 11,
#                                     'office': 1,
#                                     'old_name': 7,
#                                     'old_name:en': 7,
#                                     'old_name:zh': 6,
#                                     'operator': 332,
#                                     'operator:en': 3,
#                                     'operator:wikidata': 8,
#                                     'operator:zh': 1,
#                                     'operator:zh-yue': 1,
#                                     'parent_basin': 11,
#                                     'parking': 3,
#                                     'phone': 39,
#                                     'place': 16,
#                                     'population': 4,
#                                     'psv': 5,
#                                     'public_transport': 13,
#                                     'ref': 368,
#                                     'restriction': 3584,
#                                     'roundtrip': 8,
#                                     'route': 398,
#                                     'route_master': 56,
#                                     'service_times': 34,
#                                     'ship': 3,
#                                     'shop': 8,
#                                     'source': 395,
#                                     'source:name': 1,
#                                     'source:position': 1,
#                                     'source:tracer': 1,
#                                     'source:zoomlevel': 1,
#                                     'sport': 40,
#                                     'start_date': 30,
#                                     'subway': 3,
#                                     'surface': 3,
#                                     'symbol': 21,
#                                     'time_off': 6,
#                                     'time_on': 6,
#                                     'timezone': 3,
#                                     'timezone:note': 1,
#                                     'to': 13,
#                                     'to:en': 3,
#                                     'to:zh': 3,
#                                     'to:zh-yue': 3,
#                                     'tourism': 6,
#                                     'type': 5390,
#                                     'via': 3,
#                                     'via:en': 3,
#                                     'via:zh': 3,
#                                     'via:zh-yue': 3,
#                                     'water': 35,
#                                     'waterway': 58,
#                                     'website': 43,
#                                     'wetland': 2,
#                                     'wheelchair': 42,
#                                     'wikidata': 41,
#                                     'wikipedia': 114,
#                                     'wikipedia:en': 5,
#                                     'wikipedia:zh': 3,
#                                     'zhb_code': 12}},
#     'tag': {   'attributes': ['k', 'v'], 'count': 672332},
#     'way': {   'attributes': [   'changeset',
#                                  'uid',
#                                  'timestamp',
#                                  'version',
#                                  'user',
#                                  'id'],
#                'count': 197633,
#                'features': {   'FIXME': 5,
#                                'ON': 37,
#                                'access': 1721,
#                                'addr:city': 535,
#                                'addr:country': 5,
#                                'addr:district': 27,
#                                'addr:full': 1,
#                                'addr:housename': 354,
#                                'addr:housename:en': 1,
#                                'addr:housenumber': 7028,
#                                'addr:housenumber:en': 2,
#                                'addr:housenumber:zh': 2,
#                                'addr:place': 26,
#                                'addr:postcode': 61,
#                                'addr:province': 2,
#                                'addr:street': 6679,
#                                'admin_level': 445,
#                                'aerialway': 14,
#                                'aerialway:bubble': 1,
#                                'aerialway:duration': 1,
#                                'aerialway:occupancy': 1,
#                                'aeroway': 636,
#                                'airmark': 1,
#                                'alt_name': 658,
#                                'alt_name:en': 119,
#                                'alt_name:fr': 1,
#                                'alt_name:pt': 2,
#                                'alt_name:vi': 8,
#                                'alt_name:zh': 106,
#                                'alt_name:zh-yue': 14,
#                                'alt_name:zh_pinyin': 3,
#                                'ame': 1,
#                                'amenity': 4064,
#                                'area': 1242,
#                                'artwork_type': 1,
#                                'atm': 2,
#                                'attraction': 1,
#                                'barrier': 313,
#                                'bearing': 1,
#                                'bench': 140,
#                                'bicycle': 2733,
#                                'bicycle_parking': 1,
#                                'boat': 173,
#                                'border_type': 2,
#                                'boundary': 452,
#                                'brand': 24,
#                                'bridge': 13957,
#                                'building': 33086,
#                                'building:color': 9,
#                                'building:colour': 7,
#                                'building:facade:color': 1,
#                                'building:facade:material': 2,
#                                'building:flats': 1,
#                                'building:height': 58,
#                                'building:levels': 11858,
#                                'building:levels:underground': 8,
#                                'building:material': 53,
#                                'building:min_level': 48,
#                                'building:min_levels': 1,
#                                'building:part': 69,
#                                'building:roof': 1,
#                                'building:roof:shape': 1,
#                                'building:use': 32,
#                                'building:year': 20,
#                                'bus': 1,
#                                'cables': 57,
#                                'capacity': 65,
#                                'capacity:disabled': 1,
#                                'catmp-RoadID': 470,
#                                'cityname': 194,
#                                'club': 5,
#                                'code': 79,
#                                'colour': 2,
#                                'comment': 3,
#                                'community': 1,
#                                'community:en': 1,
#                                'community:gender': 1,
#                                'construction': 228,
#                                'constuction': 3,
#                                'contact:phone': 1,
#                                'contact:website': 1,
#                                'content': 12,
#                                'conveying': 10,
#                                'country': 3,
#                                'countryname': 190,
#                                'covered': 554,
#                                'craft': 1,
#                                'created_by': 76,
#                                'crop': 5,
#                                'crossing': 75,
#                                'cuisine': 25,
#                                'cutting': 174,
#                                'cycleway': 52,
#                                'cycleway:right': 9,
#                                'denomination': 46,
#                                'denotation': 9,
#                                'description': 3,
#                                'designation': 101,
#                                'destination': 12,
#                                'diplomatic': 1,
#                                'direction': 13,
#                                'dirindicator': 148,
#                                'disused:highway': 1,
#                                'dock': 3,
#                                'drinking_water': 1,
#                                'drinking_water:bottle': 1,
#                                'drive_through': 1,
#                                'duration': 2,
#                                'ele': 33,
#                                'electrified': 1654,
#                                'email': 62,
#                                'embankment': 158,
#                                'emergency': 919,
#                                'enclosed_area': 1,
#                                'fax': 77,
#                                'fee': 54,
#                                'fence_type': 9,
#                                'ferry': 1,
#                                'fixme': 291,
#                                'floating': 11,
#                                'foot': 3580,
#                                'footway': 413,
#                                'ford': 3,
#                                'frequency': 1402,
#                                'fuel:diesel': 6,
#                                'fuel:lpg': 2,
#                                'fuel:octane_95': 5,
#                                'fuel:octane_98': 4,
#                                'garmin_road_class': 541,
#                                'garmin_type': 852,
#                                'gauge': 1631,
#                                'generator:method': 5,
#                                'generator:output:electricity': 4,
#                                'generator:source': 6,
#                                'golf': 131,
#                                'goods': 912,
#                                'height': 208,
#                                'heritage': 1,
#                                'heritage:operator': 1,
#                                'hgv': 906,
#                                'highspeed': 187,
#                                'highway': 119065,
#                                'hiking': 7,
#                                'hires': 1,
#                                'historic': 47,
#                                'history': 3,
#                                'hoops': 3,
#                                'horse': 144,
#                                'hour_on': 10,
#                                'iata': 1,
#                                'icao': 1,
#                                'incline': 124,
#                                'industroal': 1,
#                                'information': 2,
#                                'int_name': 177,
#                                'intermittent': 1,
#                                'internet_access': 24,
#                                'internet_access:fee': 20,
#                                'is_in': 185,
#                                'is_in:en': 6,
#                                'is_in:theme_park': 54,
#                                'is_in:zh': 8,
#                                'junction': 625,
#                                'kml_folder': 4,
#                                'ladder': 1,
#                                'landuse': 9385,
#                                'lanes': 8745,
#                                'lanes:backward': 3,
#                                'lanes:bus:right': 1,
#                                'lanes:forward': 70,
#                                'lang:zh': 1,
#                                'layer': 20339,
#                                'leisure': 6127,
#                                'length': 2,
#                                'level': 64,
#                                'light_rail': 136,
#                                'line': 3,
#                                'lit': 1094,
#                                'loc_name': 25,
#                                'location': 3,
#                                'man_made': 832,
#                                'marine': 772,
#                                'maritime': 1,
#                                'maxaxleload': 3,
#                                'maxheight': 111,
#                                'maxlength': 235,
#                                'maxspeed': 3726,
#                                'maxspeed:backward': 4,
#                                'maxspeed:forward': 4,
#                                'maxstay': 8,
#                                'maxweight': 81,
#                                'maxwidth': 4,
#                                'military': 7,
#                                'min_height': 15,
#                                'mineral': 1,
#                                'minspeed': 4,
#                                'monitoring:weather': 2,
#                                'motor_vehicle': 308,
#                                'motorcar': 902,
#                                'motorcycle': 5,
#                                'motorroad': 234,
#                                'mown': 22,
#                                'mp_type': 766,
#                                'mtb': 1,
#                                'mtb:scale': 3,
#                                'museum': 1,
#                                'name': 50611,
#                                'name:': 7,
#                                'name:de': 13,
#                                'name:em': 1,
#                                'name:en': 33475,
#                                'name:es': 2,
#                                'name:fr': 281,
#                                'name:h': 1,
#                                'name:he': 2,
#                                'name:hi': 1,
#                                'name:ja': 3,
#                                'name:ko': 1,
#                                'name:lt': 2,
#                                'name:pt': 2318,
#                                'name:ru': 3,
#                                'name:sn': 1,
#                                'name:sv': 2,
#                                'name:uk': 8,
#                                'name:vi': 14,
#                                'name:yue': 14,
#                                'name:zh': 34068,
#                                'name:zh-classical': 2,
#                                'name:zh-simplified': 1,
#                                'name:zh-traditional': 1,
#                                'name:zh-yue': 609,
#                                'name:zh_pinyin': 654,
#                                'name:zh_py': 8,
#                                'name:zn': 9,
#                                'name_1': 1,
#                                'name_old': 1,
#                                'nat_name': 1,
#                                'natural': 8103,
#                                'network': 57,
#                                'nod1': 761,
#                                'nod10': 4,
#                                'nod11': 3,
#                                'nod12': 1,
#                                'nod2': 757,
#                                'nod3': 335,
#                                'nod4': 176,
#                                'nod5': 91,
#                                'nod6': 44,
#                                'nod7': 32,
#                                'nod8': 13,
#                                'nod9': 7,
#                                'noexit': 1,
#                                'note': 249,
#                                'notes': 7,
#                                'nsdi_code': 67,
#                                'office': 58,
#                                'official_name': 65,
#                                'official_name:en': 14,
#                                'official_name:pt': 30,
#                                'official_name:zh': 40,
#                                'old_name': 89,
#                                'old_name:en': 49,
#                                'old_name:zh': 45,
#                                'old_name:zh-yue': 16,
#                                'old_ref': 2,
#                                'oneway': 43693,
#                                'opening_hours': 60,
#                                'operator': 791,
#                                'operator:en': 209,
#                                'operator:wikidata': 311,
#                                'operator:zh': 206,
#                                'ownership': 1,
#                                'park_ride': 6,
#                                'parking': 520,
#                                'parking:lane:left': 1,
#                                'perimeter': 1,
#                                'phone': 146,
#                                'place': 528,
#                                'plant:output:electricity': 4,
#                                'platforms': 72,
#                                'port:category': 1,
#                                'postal_code': 10,
#                                'power': 851,
#                                'produce': 3,
#                                'proposed': 26,
#                                'psv': 2666,
#                                'public_transport': 389,
#                                'raceway': 3,
#                                'railway': 3436,
#                                'ramsar': 1,
#                                'ramsar_site_no': 1,
#                                'recycling:cans': 2,
#                                'recycling:cartons': 1,
#                                'recycling:paper': 3,
#                                'recycling:scrap_metal': 2,
#                                'recycling_type': 36,
#                                'ref': 6919,
#                                'ref:amo': 1,
#                                'ref:en': 3,
#                                'ref:kmb': 1,
#                                'ref:zh': 3,
#                                'reg_name': 2,
#                                'region': 124,
#                                'regionname': 193,
#                                'religion': 161,
#                                'residential': 2,
#                                'resource': 1,
#                                'roadid': 754,
#                                'roof:colour': 44,
#                                'roof:direction': 4,
#                                'roof:height': 8,
#                                'roof:material': 80,
#                                'roof:shape': 76,
#                                'rooms': 1,
#                                'route': 111,
#                                'routeparam': 735,
#                                'ruins': 15,
#                                'sac_scale': 33,
#                                'school': 1,
#                                'scout': 1,
#                                'seamark:anchorage:category': 10,
#                                'seamark:anchorage:restriction': 1,
#                                'seamark:information': 23,
#                                'seamark:name': 40,
#                                'seamark:name:en': 35,
#                                'seamark:name:zh': 35,
#                                'seamark:restricted_area:category': 1,
#                                'seamark:restricted_area:restriction': 6,
#                                'seamark:type': 98,
#                                'seamark:wreck:category': 1,
#                                'segregated': 920,
#                                'service': 2437,
#                                'shelter': 273,
#                                'shelter_type': 9,
#                                'ship': 63,
#                                'ship:type': 1,
#                                'shop': 418,
#                                'short_name': 180,
#                                'short_name:en': 8,
#                                'short_name:zh': 9,
#                                'sidewalk': 459,
#                                'ski': 19,
#                                'sloped_curb': 1,
#                                'smoking': 20,
#                                'smoothness': 1,
#                                'snowmobile': 19,
#                                'social_facility': 8,
#                                'social_facility:for': 10,
#                                'source': 11089,
#                                'source:bridge': 1,
#                                'source:name': 7,
#                                'source:position': 3,
#                                'source:tracer': 3,
#                                'source:zoomlevel': 3,
#                                'source_url': 73,
#                                'sport': 3204,
#                                'sport_1': 1,
#                                'sport_2': 1,
#                                'sport_3': 1,
#                                'stars': 24,
#                                'start_date': 1662,
#                                'station': 55,
#                                'step_count': 5,
#                                'subway': 82,
#                                'supervised': 11,
#                                'surface': 1691,
#                                'tactile_paving': 1,
#                                'taxi': 900,
#                                'taxon:en': 3,
#                                'tents': 1,
#                                'text': 1,
#                                'text_meaning:en': 1,
#                                'theatre:type': 3,
#                                'tidal': 1,
#                                'tiger:county': 1,
#                                'toilets': 2,
#                                'toilets:disposal': 4,
#                                'toilets:position': 1,
#                                'toll': 309,
#                                'tourism': 495,
#                                'tower:type': 2,
#                                'tracks': 92,
#                                'tracktype': 3,
#                                'traffic_calming': 1,
#                                'trail_visibility': 30,
#                                'train': 8,
#                                'tram': 98,
#                                'trees': 3,
#                                'tunnel': 2454,
#                                'turn': 2,
#                                'turn:lanes': 4,
#                                'turn:lanes:backward': 1,
#                                'turn:lanes:forward': 22,
#                                'type': 389,
#                                'url': 2,
#                                'usage': 300,
#                                'vehicle': 1805,
#                                'vehicle:conditional': 15,
#                                'voltage': 1633,
#                                'wall': 2,
#                                'waste': 3,
#                                'water': 1426,
#                                'waterway': 4428,
#                                'website': 495,
#                                'website:en': 3,
#                                'wetland': 30,
#                                'wheelchair': 275,
#                                'width': 46,
#                                'wikidata': 24,
#                                'wikimedia_commons': 1,
#                                'wikipedia': 887,
#                                'wikipedia:en': 4,
#                                'wikipedia:zh': 1,
#                                'wires': 40,
#                                'wood': 8,
#                                'zhb_code': 72}}}
